# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm
from time import sleep

# %%
def extrai_dados_preco_popular(ean):
    url_cliquefarma = f'https://www.cliquefarma.com.br/preco/site/farmacia-preco-popular/{ean}'
    headers = {'user-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}
    site = requests.get(url_cliquefarma, headers=headers)
    soup = BeautifulSoup(site.content, 'html.parser')
    link_interno_cliquefarma = soup.find('a', class_='link-oferta')['href']
    site_interno_cliquefarma = requests.get(link_interno_cliquefarma, headers=headers)
    soup_interno_cliquefarma = BeautifulSoup(site_interno_cliquefarma.content, 'html.parser')
    link = soup_interno_cliquefarma.find('a', class_='inline-block')['href']
    link_final_preco_popular = link.split('?idsku')[0]
    site_precopopular = requests.get(link_final_preco_popular, headers=headers)
    soup_site_precopopular = BeautifulSoup(site_precopopular.content, 'html.parser')
    cod_preco_popular = soup_site_precopopular.find('div', class_='productReference').get_text()
    preco_preco_popular = soup_site_precopopular.find('strong', class_='skuBestPrice').get_text()
    preco_preco_popular = float(preco_preco_popular.split('R$')[1].replace(',', '.'))
    lst_preco_popular = [link_final_preco_popular, cod_preco_popular, preco_preco_popular]
    return lst_preco_popular

def extrai_dados_saojoao(ean):
    url_principal = f'https://www.saojoaofarmacias.com.br/{ean}'
    headers = {'user-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}
    site = requests.get(url_principal, headers=headers)
    soup = BeautifulSoup(site.content, 'html.parser')
    link_interno_saojoao = "https://www.saojoaofarmacias.com.br" + f"{soup.find('a', class_='vtex-product-summary-2-x-clearLink vtex-product-summary-2-x-clearLink--vitrine h-100 flex flex-column')['href']}"
    site_saojoao = requests.get(link_interno_saojoao, headers=headers)
    soup_site_saojoao = BeautifulSoup(site_saojoao.content, 'html.parser')
    cod_saojoao = ''
    preco_saojoao = soup_site_saojoao.find('span', class_='sjdigital-custom-apps-0-x-currencyContainer').get_text()
    preco_saojoao = float(preco_saojoao.replace('R$','').replace('.','').replace(',','.'))
    lst_saojoao = [link_interno_saojoao, cod_saojoao, preco_saojoao]
    return lst_saojoao

def extrai_dados_paguemenos(ean):
    url_principal = f'https://www.paguemenos.com.br/{ean}'
    headers = {'user-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}
    site = requests.get(url_principal, headers=headers)
    soup = BeautifulSoup(site.content, 'html.parser')
    link_interno_paguemenos = "https://www.paguemenos.com.br" + f"{soup.find('a', class_='vtex-product-summary-2-x-clearLink')['href']}"
    site_paguemenos = requests.get(link_interno_paguemenos, headers=headers)
    soup_site_paguemenos = BeautifulSoup(site_paguemenos.content, 'html.parser')
    cod_paguemenos = soup_site_paguemenos.find('div', class_='pr0')
    cod_paguemenos = cod_paguemenos.find('p').get_text()
    cod_paguemenos = cod_paguemenos.split(' ')[1]
    preco_paguemenos = soup_site_paguemenos.find('span', class_='vtex-store-components-3-x-sellingPrice vtex-store-components-3-x-sellingPriceValue t-heading-2-s dib ph2 vtex-store-components-3-x-price_sellingPrice').get_text()
    preco_paguemenos = float(preco_paguemenos.replace('R$','').replace('.','').replace(',','.'))
    lst_paguemenos = [link_interno_paguemenos, cod_paguemenos, preco_paguemenos]
    return lst_paguemenos

def extrai_dados_raia(ean):
    url_google = f'https://www.google.com/search?q=RAIA+{ean}'
    headers = {'user-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}
    site = requests.get(url_google, headers=headers)
    soup = BeautifulSoup(site.content, 'html.parser')
    link_interno_google = soup.find('div', class_='MjjYud').find('a')['href']
    site_raia = requests.get(link_interno_google, headers=headers)
    soup_site_raia = BeautifulSoup(site_raia.content, 'html.parser')
    cod_raia = soup_site_raia.find('span', class_='RaiaProductDescriptionstyles__Data-sc-1ijezxr-8').get_text()
    preco_raia = soup_site_raia.find('span', class_='ProductPricestyles__Price-i0kwh2-4').get_text()
    preco_raia = float(preco_raia.split('R$ ')[1].replace(',', '.'))
    lst_raia = [link_interno_google, cod_raia, preco_raia]
    return lst_raia

# %%
def extrai_dados_panvel(ean):
    url_google = f'https://www.google.com/search?q=panvel+{ean}'
    headers = {'user-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}
    site = requests.get(url_google, headers=headers)
    soup = BeautifulSoup(site.content, 'html.parser')
    link_interno_google = soup.find('div', class_='yuRUbf').find('a')['href']
    site_panvel = requests.get(link_interno_google, headers=headers)
    soup_site_panvel = BeautifulSoup(site_panvel.content, 'html.parser')
    cod_panvel = link_interno_google.split('/p-')[-1]
    preco_panvel = soup_site_panvel.find('span', class_='deal-price').get_text()
    #preco_panvel = float(preco_panvel.split('R$ ')[1].replace(',', '.'))
    #lst_panvel = [link_interno_google, cod_panvel, preco_panvel]
    return cod_panvel

# %%
extrai_dados_panvel('7891058022136')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 extrai_dados_panvel('7891058022136')
#
# Cell In[78], line 10, in extrai_dados_panvel(ean)
#       8 soup_site_panvel = BeautifulSoup(site_panvel.content, 'html.parser')
#       9 cod_panvel = link_interno_google.split('/p-')[-1]
# ---> 10 preco_panvel = soup_site_panvel.find('span', class_='deal-price').get_text()
#      11 #preco_panvel = float(preco_panvel.split('R$ ')[1].replace(',', '.'))
#      12 #lst_panvel = [link_interno_google, cod_panvel, preco_panvel]
#      13 return cod_panvel
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
data = pd.read_excel('rx.xls')
data
# Out:
#       codshopfarma    laboratorio            ean  \
# 0            18717        MOMENTA  7891317129941
# 1           122060        MOMENTA  7891317129958
# 2            54135        MOMENTA  7891317019297
# 3           107541           EMS   7896004817477
# 4           104826         HYPERA  7897595901927
# ...            ...            ...            ...
# 3963        109701       ALLERGAN  7897316805688
# 3964         15657       ALLERGAN  7897316805619
# 3965        111924       ALLERGAN  7897316805442
# 3966        102653            GSK  7896269901898
# 3967         12178  UCB BIOPHARMA  7896672201738
#
#                              produto  preco_venda  preco_compra         margem
# 0                  20 BI 335MG 10CAP        87.99         66.69      31.938821
# 1                  20 BI 335MG 30CAP       181.90        132.28      37.511340
# 2                   20 BI 335MG 5CAP        59.99         43.18      38.930060
# 3        A SAUDE DA MULHER LIQ 150ML        16.50         11.90      38.655462
# 4                    AAS 100MG 120CP        82.00         54.48      50.513950
# ...                              ...          ...           ...            ...
# 3963         ZYMAR XD 5MG/ML COL 5ML        80.00         49.40      61.943320
# 3964      ZYPRED 3MG+10MG/ML COL 3ML        41.00         28.26      45.081387
# 3965      ZYPRED 3MG+10MG/ML COL 6ML        83.39         51.75      61.140097
# 3966            ZYRTEC 10MG 12CP REV        78.18          0.01  781700.000000
# 3967           ZYXEM 5MG/ML GTS 20ML        75.50         39.18      92.700357
#
# [3968 rows x 7 columns]

# %%
lst_interna = []
for index, row in tqdm(data.iterrows()):
    ean = row['ean']
    name = row['produto']
    codigo_shopfarma = row['codshopfarma']
    preco_shopfarma = row['preco_venda']
    try:
        lst_preco_popular = extrai_dados_preco_popular(ean)
    except:
        lst_preco_popular = ['','','']
    try:
        lst_raia = extrai_dados_raia(ean)
    except:
        lst_raia = ['','','']
    try:
        lst_paguemenos = extrai_dados_paguemenos(ean)
    except:
        lst_paguemenos = ['','','']
    try:
        lst_saojoao = extrai_dados_saojoao(ean)
    except:
        lst_saojoao = ['','','']
    dados = ean, name, codigo_shopfarma, preco_shopfarma, lst_preco_popular[0], lst_preco_popular[1], lst_preco_popular[2], lst_raia[0], lst_raia[1], lst_raia[2], lst_paguemenos[0], lst_paguemenos[1], lst_paguemenos[2], lst_saojoao[0], lst_saojoao[1], lst_saojoao[2]
    lst_interna.append(dados)
# Out:
# 3968it [14:05:35, 12.79s/it]

# %%
df = pd.DataFrame(lst_interna, columns=['ean', 'produto', 'codshopfarma', 'preco_shopfarma', 'link_preco_popular', 'cod_preco_popular', 'preco_preco_popular', 'link_raia', 'cod_raia', 'preco_raia', 'link_paguemenos', 'cod_paguemenos', 'preco_paguemenos', 'link_saojoao', 'cod_saojoao', 'preco_saojoao'])

# %%
df
# Out:
#                 ean                         produto  codshopfarma  \
# 0     7891317129941               20 BI 335MG 10CAP         18717
# 1     7891317129958               20 BI 335MG 30CAP        122060
# 2     7891317019297                20 BI 335MG 5CAP         54135
# 3     7896004817477     A SAUDE DA MULHER LIQ 150ML        107541
# 4     7897595901927                 AAS 100MG 120CP        104826
# ...             ...                             ...           ...
# 3963  7897316805688         ZYMAR XD 5MG/ML COL 5ML        109701
# 3964  7897316805619      ZYPRED 3MG+10MG/ML COL 3ML         15657
# 3965  7897316805442      ZYPRED 3MG+10MG/ML COL 6ML        111924
# 3966  7896269901898            ZYRTEC 10MG 12CP REV        102653
# 3967  7896672201738           ZYXEM 5MG/ML GTS 20ML         12178
#
#       preco_shopfarma                                 link_preco_popular  \
# 0               87.99  https://www.precopopular.com.br/20-bi-335mg-co...
# 1              181.90  https://www.precopopular.com.br/20-bi-335mg-co...
# 2               59.99
# 3               16.50  https://www.precopopular.com.br/saude-da-mulhe...
# 4               82.00  https://www.precopopular.com.br/a-a-s-infantil...
# ...               ...                                                ...
# 3963            80.00
# 3964            41.00
# 3965            83.39
# 3966            78.18
# 3967            75.50
#
#      cod_preco_popular preco_preco_popular  \
# 0               727488               82.95
# 1               727489              207.95
# 2
# 3               531815               17.99
# 4               691679               75.18
# ...                ...                 ...
# 3963
# 3964
# 3965
# 3966
# 3967
#
#                                               link_raia cod_raia preco_raia  \
# 0
# 1
# 2     https://drogaraia.com.br/20-bi-antidiarreico-5...    40038      55.83
# 3
# 4
# ...                                                 ...      ...        ...
# 3963
# 3964
# 3965
# 3966
# 3967
#
#                                         link_paguemenos cod_paguemenos  \
# 0
# 1
# 2     https://www.paguemenos.com.br/20bi-com-5-capsu...          95204
# 3     https://www.paguemenos.com.br/saude-mulher-150...           4411
# 4     https://www.paguemenos.com.br/aas-100mg-infant...          17084
# ...                                                 ...            ...
# 3963
# 3964
# 3965
# 3966
# 3967
#
#      preco_paguemenos                                       link_saojoao  \
# 0                      https://www.saojoaofarmacias.com.br/20bi-10cap...
# 1                      https://www.saojoaofarmacias.com.br/20bi-30cap...
# 2               55.25
# 3               19.15  https://www.saojoaofarmacias.com.br/a-saude-da...
# 4               79.35  https://www.saojoaofarmacias.com.br/aas-100mg-...
# ...               ...                                                ...
# 3963
# 3964
# 3965
# 3966
# 3967
#
#      cod_saojoao preco_saojoao
# 0                        74.39
# 1                       175.59
# 2
# 3                        18.51
# 4                        65.69
# ...          ...           ...
# 3963
# 3964
# 3965
# 3966
# 3967
#
# [3968 rows x 16 columns]

# %%
df_preco = df[['ean', 'produto', 'codshopfarma', 'preco_shopfarma', 'preco_preco_popular', 'preco_raia', 'preco_paguemenos', 'preco_saojoao']]
df_preco
# Out:
#                 ean                         produto  codshopfarma  \
# 0     7891317129941               20 BI 335MG 10CAP         18717
# 1     7891317129958               20 BI 335MG 30CAP        122060
# 2     7891317019297                20 BI 335MG 5CAP         54135
# 3     7896004817477     A SAUDE DA MULHER LIQ 150ML        107541
# 4     7897595901927                 AAS 100MG 120CP        104826
# ...             ...                             ...           ...
# 3963  7897316805688         ZYMAR XD 5MG/ML COL 5ML        109701
# 3964  7897316805619      ZYPRED 3MG+10MG/ML COL 3ML         15657
# 3965  7897316805442      ZYPRED 3MG+10MG/ML COL 6ML        111924
# 3966  7896269901898            ZYRTEC 10MG 12CP REV        102653
# 3967  7896672201738           ZYXEM 5MG/ML GTS 20ML         12178
#
#       preco_shopfarma preco_preco_popular preco_raia preco_paguemenos  \
# 0               87.99               82.95
# 1              181.90              207.95
# 2               59.99                          55.83            55.25
# 3               16.50               17.99                       19.15
# 4               82.00               75.18                       79.35
# ...               ...                 ...        ...              ...
# 3963            80.00
# 3964            41.00
# 3965            83.39
# 3966            78.18
# 3967            75.50
#
#      preco_saojoao
# 0            74.39
# 1           175.59
# 2
# 3            18.51
# 4            65.69
# ...            ...
# 3963
# 3964
# 3965
# 3966
# 3967
#
# [3968 rows x 8 columns]

# %%
df.to_csv('dados_rx_concorrentes.csv', index=False)
